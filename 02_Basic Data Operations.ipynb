# %%
import pandas as pd

# %%
#pipe delimited
reads = pd.read_table('https://www.nrc.gov/reading-rm/doc-collections/event-status/reactor-status/2009/2009PowerStatus.txt')
reads.head()
# Out:
#                  ReportDt|Unit|Power
# 0  12/31/2009|Arkansas Nuclear 1|100
# 1  12/31/2009|Arkansas Nuclear 2|100
# 2     12/31/2009|Beaver Valley 1|100
# 3     12/31/2009|Beaver Valley 2|100
# 4         12/31/2009|Braidwood 1|100

# %%
reads = pd.read_table('https://www.nrc.gov/reading-rm/doc-collections/event-status/reactor-status/2009/2009PowerStatus.txt', sep='|')
reads.head()
# Out:
#      ReportDt                Unit  Power
# 0  12/31/2009  Arkansas Nuclear 1    100
# 1  12/31/2009  Arkansas Nuclear 2    100
# 2  12/31/2009     Beaver Valley 1    100
# 3  12/31/2009     Beaver Valley 2    100
# 4  12/31/2009         Braidwood 1    100

# %%
#tsv
employee = pd.read_table('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/DataTablesExample_TSV.tsv')
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date      Salary
# 0  2008/11/28    $162,700
# 1  2009/10/09  $1,200,000
# 2  2009/01/12     $86,000
# 3  2012/10/13    $132,000
# 4  2011/06/07    $206,850

# %%
#choose certain columns
cols=['Name','Position']
employee = pd.read_table('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/DataTablesExample_TSV.tsv')
employee[cols].head()
# Out:
#              Name                       Position
# 0      Airi Satou                     Accountant
# 1  Angelica Ramos  Chief Executive Officer (CEO)
# 2      Ashton Cox        Junior Technical Author
# 3   Bradley Greer              Software Engineer
# 4  Brenden Wagner              Software Engineer

# %%
#choose certain rows
employee = pd.read_table('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/DataTablesExample_TSV.tsv', nrows = 4)
employee
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
#
#    Start date      Salary
# 0  2008/11/28    $162,700
# 1  2009/10/09  $1,200,000
# 2  2009/01/12     $86,000
# 3  2012/10/13    $132,000

# %%
#display datatypes
employee = pd.read_table('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/DataTablesExample_TSV.tsv')
employee.dtypes
# Out:
# Name          object
# Position      object
# Office        object
# Age            int64
# Start date    object
# Salary        object
# dtype: object

# %%
#display integer datatypes
import numpy as np
employee = pd.read_table('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/DataTablesExample_TSV.tsv')
employee.select_dtypes(include = [np.number]).dtypes
# Out:
# Age    int64
# dtype: object

# %%
#inbuilt methods for data analysis
employee.describe()
# Out:
#              Age
# count  57.000000
# mean   42.736842
# std    14.877507
# min    19.000000
# 25%    30.000000
# 50%    42.000000
# 75%    56.000000
# max    66.000000

# %%
#number of rows and columns
employee.shape
# Out:
# (57, 6)

# %%
#type of object
type(employee)
# Out:
# pandas.core.frame.DataFrame

# %%
employee = pd.read_table('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/DataTablesExample_TSV.tsv')
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date      Salary
# 0  2008/11/28    $162,700
# 1  2009/10/09  $1,200,000
# 2  2009/01/12     $86,000
# 3  2012/10/13    $132,000
# 4  2011/06/07    $206,850

# %%
#concatinating 2 columns
employee['Name Salary']=employee['Name']+employee['Salary']
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date      Salary               name salary               Name Salary
# 0  2008/11/28    $162,700        Airi Satou$162,700        Airi Satou$162,700
# 1  2009/10/09  $1,200,000  Angelica Ramos$1,200,000  Angelica Ramos$1,200,000
# 2  2009/01/12     $86,000         Ashton Cox$86,000         Ashton Cox$86,000
# 3  2012/10/13    $132,000     Bradley Greer$132,000     Bradley Greer$132,000
# 4  2011/06/07    $206,850    Brenden Wagner$206,850    Brenden Wagner$206,850

# %%
employee.drop('Office', axis=1, inplace=True)
employee.head()
# Out:
#              Name                       Position  Age  Start date      Salary  \
# 0      Airi Satou                     Accountant   33  2008/11/28    $162,700
# 1  Angelica Ramos  Chief Executive Officer (CEO)   47  2009/10/09  $1,200,000
# 2      Ashton Cox        Junior Technical Author   66  2009/01/12     $86,000
# 3   Bradley Greer              Software Engineer   41  2012/10/13    $132,000
# 4  Brenden Wagner              Software Engineer   28  2011/06/07    $206,850
#
#                 name salary               Name Salary
# 0        Airi Satou$162,700        Airi Satou$162,700
# 1  Angelica Ramos$1,200,000  Angelica Ramos$1,200,000
# 2         Ashton Cox$86,000         Ashton Cox$86,000
# 3     Bradley Greer$132,000     Bradley Greer$132,000
# 4    Brenden Wagner$206,850    Brenden Wagner$206,850

# %%
employee = pd.read_table('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/DataTablesExample_TSV.tsv')
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date      Salary
# 0  2008/11/28    $162,700
# 1  2009/10/09  $1,200,000
# 2  2009/01/12     $86,000
# 3  2012/10/13    $132,000
# 4  2011/06/07    $206,850

# %%
#renaming column
cols =['Name','Posistion', 'Ofc','Age','SDate','Sal']
employee.columns = cols
employee.head()
# Out:
#              Name                      Posistion            Ofc  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#         SDate         Sal
# 0  2008/11/28    $162,700
# 1  2009/10/09  $1,200,000
# 2  2009/01/12     $86,000
# 3  2012/10/13    $132,000
# 4  2011/06/07    $206,850

# %%
employee = pd.read_table('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/DataTablesExample_TSV.tsv')
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date      Salary
# 0  2008/11/28    $162,700
# 1  2009/10/09  $1,200,000
# 2  2009/01/12     $86,000
# 3  2012/10/13    $132,000
# 4  2011/06/07    $206,850

# %%
#sorting Data
employee.sort_values(by='Age', ascending=True).head()
# Out:
#                    Name               Position         Office  Age  \
# 48  Tatyana Fitzpatrick      Regional Director         London   19
# 45            Shou Itou     Regional Marketing          Tokyo   20
# 7          Caesar Vance      Pre-Sales Support       New York   21
# 32           Lael Greer  Systems Administrator         London   21
# 18         Gavin Cortez            Team Leader  San Francisco   22
#
#     Start date    Salary
# 48  2010/03/17  $385,750
# 45  2011/08/14  $163,000
# 7   2011/12/12  $106,450
# 32  2009/02/27  $103,500
# 18  2008/10/26  $235,500

# %%
employee['Name'].sort_values()
# Out:
# 0              Airi Satou
# 1          Angelica Ramos
# 2              Ashton Cox
# 3           Bradley Greer
# 4          Brenden Wagner
# 5      Brielle Williamson
# 6              Bruno Nash
# 7            Caesar Vance
# 8            Cara Stevens
# 9            Cedric Kelly
# 10        Charde Marshall
# 11          Colleen Hurst
# 12               Dai Rios
# 13           Donna Snider
# 14           Doris Wilder
# 15           Finn Camacho
# 16            Fiona Green
# 17        Garrett Winters
# 18           Gavin Cortez
# 19            Gavin Joyce
# 20          Gloria Little
# 21          Haley Kennedy
# 22        Hermione Butler
# 23        Herrod Chandler
# 24           Hope Fuentes
# 25        Howard Hatfield
# 26       Jackson Bradshaw
# 27            Jena Gaines
# 28       Jenette Caldwell
# 29        Jennifer Acosta
# 30         Jennifer Chang
# 31        Jonas Alexander
# 32             Lael Greer
# 33         Martena Mccray
# 34          Michael Bruce
# 35          Michael Silva
# 36         Michelle House
# 37           Olivia Liang
# 38              Paul Byrd
# 39      Prescott Bartlett
# 40            Quinn Flynn
# 41         Rhona Davidson
# 42        Sakura Yamamoto
# 43          Serge Baldwin
# 44            Shad Decker
# 45              Shou Itou
# 46            Sonya Frost
# 47             Suki Burks
# 48    Tatyana Fitzpatrick
# 49            Thor Walton
# 50            Tiger Nixon
# 51         Timothy Mooney
# 52           Unity Butler
# 53         Vivian Harrell
# 54             Yuri Berry
# 55          Zenaida Frank
# 56         Zorita Serrano
# Name: Name, dtype: object

# %%
#filtering
employee[employee.Age<25]
# Out:
#                    Name                     Position         Office  Age  \
# 7          Caesar Vance            Pre-Sales Support       New York   21
# 9          Cedric Kelly  Senior Javascript Developer      Edinburgh   22
# 14         Doris Wilder              Sales Assistant         Sydney   23
# 18         Gavin Cortez                  Team Leader  San Francisco   22
# 32           Lael Greer        Systems Administrator         London   21
# 40          Quinn Flynn                 Support Lead      Edinburgh   22
# 45            Shou Itou           Regional Marketing          Tokyo   20
# 46          Sonya Frost            Software Engineer      Edinburgh   23
# 48  Tatyana Fitzpatrick            Regional Director         London   19
#
#     Start date    Salary
# 7   2011/12/12  $106,450
# 9   2012/03/29  $433,060
# 14  2010/09/20   $85,600
# 18  2008/10/26  $235,500
# 32  2009/02/27  $103,500
# 40  2013/03/03  $342,000
# 45  2011/08/14  $163,000
# 46  2008/12/13  $103,600
# 48  2010/03/17  $385,750

# %%
employee[(employee.Age<25) & (employee.Name == 'Shou Itou')]
# Out:
#          Name            Position Office  Age  Start date    Salary
# 45  Shou Itou  Regional Marketing  Tokyo   20  2011/08/14  $163,000

# %%
cols = ['Name' , 'Position']
employee[employee.Age<25][cols].head()
# Out:
#             Name                     Position
# 7   Caesar Vance            Pre-Sales Support
# 9   Cedric Kelly  Senior Javascript Developer
# 14  Doris Wilder              Sales Assistant
# 18  Gavin Cortez                  Team Leader
# 32    Lael Greer        Systems Administrator

# %%
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date      Salary
# 0  2008/11/28    $162,700
# 1  2009/10/09  $1,200,000
# 2  2009/01/12     $86,000
# 3  2012/10/13    $132,000
# 4  2011/06/07    $206,850

# %%
employee.mean()
# Out:
# Age    42.736842
# dtype: float64

# %%
employee.Name.str.upper().head()
# Out:
# 0        AIRI SATOU
# 1    ANGELICA RAMOS
# 2        ASHTON COX
# 3     BRADLEY GREER
# 4    BRENDEN WAGNER
# Name: Name, dtype: object

# %%
employee.Name.str.lower().head()
# Out:
# 0        airi satou
# 1    angelica ramos
# 2        ashton cox
# 3     bradley greer
# 4    brenden wagner
# Name: Name, dtype: object

# %%
employee.Position.str.contains('Software')
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46     True
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55     True
# 56     True
# Name: Position, dtype: bool

# %%
employee[employee.Position.str.contains('Software')]
# Out:
#               Name           Position         Office  Age  Start date  \
# 3    Bradley Greer  Software Engineer         London   41  2012/10/13
# 4   Brenden Wagner  Software Engineer  San Francisco   28  2011/06/07
# 6       Bruno Nash  Software Engineer         London   38  2011/05/03
# 46     Sonya Frost  Software Engineer      Edinburgh   23  2008/12/13
# 55   Zenaida Frank  Software Engineer       New York   63  2010/01/04
# 56  Zorita Serrano  Software Engineer  San Francisco   56  2012/06/01
#
#       Salary
# 3   $132,000
# 4   $206,850
# 6   $163,500
# 46  $103,600
# 55  $125,250
# 56  $115,000

# %%
employee.head()
employee.Position.str.replace('Engineer','Developer')
# Out:
# 0                        Accountant
# 1     Chief Executive Officer (CEO)
# 2           Junior Technical Author
# 3                Software Developer
# 4                Software Developer
# 5            Integration Specialist
# 6                Software Developer
# 7                 Pre-Sales Support
# 8                   Sales Assistant
# 9       Senior Javascript Developer
# 10                Regional Director
# 11             Javascript Developer
# 12                   Personnel Lead
# 13                 Customer Support
# 14                  Sales Assistant
# 15                Support Developer
# 16    Chief Operating Officer (COO)
# 17                       Accountant
# 18                      Team Leader
# 19                        Developer
# 20            Systems Administrator
# 21        Senior Marketing Designer
# 22                Regional Director
# 23                  Sales Assistant
# 24                        Secretary
# 25                   Office Manager
# 26                         Director
# 27                   Office Manager
# 28                 Development Lead
# 29      Junior Javascript Developer
# 30                Regional Director
# 31                        Developer
# 32            Systems Administrator
# 33               Post-Sales support
# 34             Javascript Developer
# 35               Marketing Designer
# 36           Integration Specialist
# 37                Support Developer
# 38    Chief Financial Officer (CFO)
# 39                 Technical Author
# 40                     Support Lead
# 41           Integration Specialist
# 42                Support Developer
# 43                 Data Coordinator
# 44                Regional Director
# 45               Regional Marketing
# 46               Software Developer
# 47                        Developer
# 48                Regional Director
# 49                        Developer
# 50                 System Architect
# 51                   Office Manager
# 52               Marketing Designer
# 53             Financial Controller
# 54    Chief Marketing Officer (CMO)
# 55               Software Developer
# 56               Software Developer
# Name: Position, dtype: object

# %%
employee.Age.min()
# Out:
# 19

# %%
employee.Age.max()
# Out:
# 66

# %%
employee.groupby('Position').Age.min()
# Out:
# Position
# Accountant                       33
# Chief Executive Officer (CEO)    47
# Chief Financial Officer (CFO)    64
# Chief Marketing Officer (CMO)    40
# Chief Operating Officer (COO)    48
# Customer Support                 27
# Data Coordinator                 64
# Developer                        30
# Development Lead                 30
# Director                         65
# Financial Controller             62
# Integration Specialist           37
# Javascript Developer             29
# Junior Javascript Developer      43
# Junior Technical Author          66
# Marketing Designer               47
# Office Manager                   30
# Personnel Lead                   35
# Post-Sales support               46
# Pre-Sales Support                21
# Regional Director                19
# Regional Marketing               20
# Sales Assistant                  23
# Secretary                        41
# Senior Javascript Developer      22
# Senior Marketing Designer        43
# Software Engineer                23
# Support Engineer                 37
# Support Lead                     22
# System Architect                 61
# Systems Administrator            21
# Team Leader                      22
# Technical Author                 27
# Name: Age, dtype: int64

# %%
employee.groupby('Position').Age.agg(['count','min','max'])
# Out:
#                                count  min  max
# Position
# Accountant                         2   33   63
# Chief Executive Officer (CEO)      1   47   47
# Chief Financial Officer (CFO)      1   64   64
# Chief Marketing Officer (CMO)      1   40   40
# Chief Operating Officer (COO)      1   48   48
# Customer Support                   1   27   27
# Data Coordinator                   1   64   64
# Developer                          4   30   61
# Development Lead                   1   30   30
# Director                           1   65   65
# Financial Controller               1   62   62
# Integration Specialist             3   37   61
# Javascript Developer               2   29   39
# Junior Javascript Developer        1   43   43
# Junior Technical Author            1   66   66
# Marketing Designer                 2   47   66
# Office Manager                     3   30   51
# Personnel Lead                     1   35   35
# Post-Sales support                 1   46   46
# Pre-Sales Support                  1   21   21
# Regional Director                  5   19   51
# Regional Marketing                 1   20   20
# Sales Assistant                    3   23   59
# Secretary                          1   41   41
# Senior Javascript Developer        1   22   22
# Senior Marketing Designer          1   43   43
# Software Engineer                  6   23   63
# Support Engineer                   3   37   64
# Support Lead                       1   22   22
# System Architect                   1   61   61
# Systems Administrator              2   21   59
# Team Leader                        1   22   22
# Technical Author                   1   27   27

# %%
#loc - choose number of rows and column
employee = pd.read_table('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/DataTablesExample_TSV.tsv')

#row 0, all col
employee.loc[0, :]
# Out:
# Name          Airi Satou
# Position      Accountant
# Office             Tokyo
# Age                   33
# Start date    2008/11/28
# Salary          $162,700
# Name: 0, dtype: object

# %%
#row 0-2, all col
employee.loc[0:2, :]
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
#
#    Start date      Salary
# 0  2008/11/28    $162,700
# 1  2009/10/09  $1,200,000
# 2  2009/01/12     $86,000

# %%
#row 0-2, 2 col
employee.loc[0:2, ['Name','Position']]
# Out:
#              Name                       Position
# 0      Airi Satou                     Accountant
# 1  Angelica Ramos  Chief Executive Officer (CEO)
# 2      Ashton Cox        Junior Technical Author

# %%
#row 0-2, 3 col
employee.loc[0:2, 'Name':'Office']
# Out:
#              Name                       Position         Office
# 0      Airi Satou                     Accountant          Tokyo
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London
# 2      Ashton Cox        Junior Technical Author  San Francisco

# %%
#rows with certain condition
employee.loc[employee.Position == 'Accountant',:]
# Out:
#                Name    Position Office  Age  Start date    Salary
# 0        Airi Satou  Accountant  Tokyo   33  2008/11/28  $162,700
# 17  Garrett Winters  Accountant  Tokyo   63  2011/07/25  $170,750

# %%
#dropna - drop rows with missing values
employee = pd.read_table('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/dropnaExample_TSV.tsv')
employee.head()
# Out:
#              Name                       Position         Office  Age  \
# 0      Airi Satou                     Accountant          Tokyo   33
# 1  Angelica Ramos  Chief Executive Officer (CEO)         London   47
# 2      Ashton Cox        Junior Technical Author  San Francisco   66
# 3   Bradley Greer              Software Engineer         London   41
# 4  Brenden Wagner              Software Engineer  San Francisco   28
#
#    Start date    Salary
# 0  2008/11/28  $162,700
# 1  2009/10/09       NaN
# 2  2009/01/12       NaN
# 3  2012/10/13       NaN
# 4  2011/06/07  $206,850

# %%
employee.shape
# Out:
# (57, 6)

# %%
#drop values with all missing values in any columns
employee.dropna(how='any').shape
# Out:
# (54, 6)

# %%
#drop values with all missing values in specific columns
employee.dropna(subset=['Name','Salary']).shape
# Out:
# (54, 6)

# %%
#fillna

# %%
milkprod = pd.read_csv('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/MonthlyMilkProduction.csv')
milkprod.head()
# Out:
#      Month  Monthly milk production (pounds per cow)
# 0  1962-01                                       589
# 1  1962-02                                       561
# 2  1962-03                                       640
# 3  1962-04                                       656
# 4  1962-05                                       727

# %%
milkprod.plot()

# %%
#joins

#create dummy data
dataframe1 = pd.DataFrame({
    "employee":["ABC","XYZ","PQR"],
    "salary":["100000","125000","80000"]
})

dataframe1
# Out:
#   employee  salary
# 0      ABC  100000
# 1      XYZ  125000
# 2      PQR   80000

# %%
dataframe2 = pd.DataFrame({
    "employee":["ABC","XYZ","LMN"],
    "salary":["100000","125000","90000"]
})

dataframe2
# Out:
#   employee  salary
# 0      ABC  100000
# 1      XYZ  125000
# 2      LMN   90000

# %%
#inner join
dataframe3 = pd.merge(dataframe1,dataframe2, on='employee')
dataframe3
# Out:
#   employee salary_x salary_y
# 0      ABC   100000   100000
# 1      XYZ   125000   125000

# %%
#outer join
dataframe3 = pd.merge(dataframe1,dataframe2, on='employee', how='outer')
dataframe3
# Out:
#   employee salary_x salary_y
# 0      ABC   100000   100000
# 1      XYZ   125000   125000
# 2      PQR    80000      NaN
# 3      LMN      NaN    90000

# %%
#left join
dataframe3 = pd.merge(dataframe1,dataframe2, on='employee', how='left')
dataframe3
# Out:
#   employee salary_x salary_y
# 0      ABC   100000   100000
# 1      XYZ   125000   125000
# 2      PQR    80000      NaN

# %%
#right join
dataframe3 = pd.merge(dataframe1,dataframe2, on='employee', how='right')
dataframe3
# Out:
#   employee salary_x salary_y
# 0      ABC   100000   100000
# 1      XYZ   125000   125000
# 2      LMN      NaN    90000

# %%
#pivot
webtraffic = pd.read_csv('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/PivotExample.csv')
webtraffic
# Out:
#         Date Page_name  hits
# 0   1/1/2018       ABC    23
# 1   1/1/2018       CDE    34
# 2   1/1/2018       JKL     2
# 3   1/1/2018       MNO    45
# 4   1/2/2018       ABC    21
# 5   1/2/2018       CDE    54
# 6   1/2/2018       JKL    65
# 7   1/2/2018       MNO   123
# 8   1/3/2018       ABC    28
# 9   1/3/2018       CDE    48
# 10  1/3/2018       JKL    24
# 11  1/3/2018       MNO    13

# %%
webtraffic.pivot(index='Page_name', columns='Date')
# Out:
#               hits
# Date      1/1/2018 1/2/2018 1/3/2018
# Page_name
# ABC             23       21       28
# CDE             34       54       48
# JKL              2       65       24
# MNO             45      123       13

# %%
#Pivot table
webtraffic.pivot_table(index='Page_name', aggfunc='sum')
# Out:
#            hits
# Page_name
# ABC          72
# CDE         136
# JKL          91
# MNO         181

# %%
#Pivot table
webtraffic.pivot_table(index='Page_name', aggfunc='mean')
# Out:
#                 hits
# Page_name
# ABC        24.000000
# CDE        45.333333
# JKL        30.333333
# MNO        60.333333

# %%
#Pivot table
webtraffic.pivot_table(index='Page_name', aggfunc='count')
# Out:
#            Date  hits
# Page_name
# ABC           3     3
# CDE           3     3
# JKL           3     3
# MNO           3     3

# %%
#shift
fb_finance = pd.read_csv('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/FB.csv')
fb_finance.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0  2/19/2019  160.500000  164.149994  160.330002  162.289993  162.289993
# 1  2/20/2019  162.250000  163.720001  161.250000  162.559998  162.559998
# 2  2/21/2019  161.929993  162.240005  159.589996  160.039993  160.039993
# 3  2/22/2019  160.580002  162.410004  160.309998  161.889999  161.889999
# 4  2/25/2019  163.070007  166.070007  162.899994  164.619995  164.619995
#
#      Volume
# 0  14345400
# 1  11770700
# 2  15607800
# 3  15858500
# 4  18737100

# %%
fb_finance.shift(1).head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0        NaN         NaN         NaN         NaN         NaN         NaN
# 1  2/19/2019  160.500000  164.149994  160.330002  162.289993  162.289993
# 2  2/20/2019  162.250000  163.720001  161.250000  162.559998  162.559998
# 3  2/21/2019  161.929993  162.240005  159.589996  160.039993  160.039993
# 4  2/22/2019  160.580002  162.410004  160.309998  161.889999  161.889999
#
#        Volume
# 0         NaN
# 1  14345400.0
# 2  11770700.0
# 3  15607800.0
# 4  15858500.0

# %%
fb_finance.shift(-1).head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0  2/20/2019  162.250000  163.720001  161.250000  162.559998  162.559998
# 1  2/21/2019  161.929993  162.240005  159.589996  160.039993  160.039993
# 2  2/22/2019  160.580002  162.410004  160.309998  161.889999  161.889999
# 3  2/25/2019  163.070007  166.070007  162.899994  164.619995  164.619995
# 4  2/26/2019  164.339996  166.240005  163.800003  164.130005  164.130005
#
#        Volume
# 0  11770700.0
# 1  15607800.0
# 2  15858500.0
# 3  18737100.0
# 4  13784100.0

# %%
#calculate stock price delta
fb_finance['previous_closing_price']=fb_finance['Close'].shift(1)
fb_finance.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0  2/19/2019  160.500000  164.149994  160.330002  162.289993  162.289993
# 1  2/20/2019  162.250000  163.720001  161.250000  162.559998  162.559998
# 2  2/21/2019  161.929993  162.240005  159.589996  160.039993  160.039993
# 3  2/22/2019  160.580002  162.410004  160.309998  161.889999  161.889999
# 4  2/25/2019  163.070007  166.070007  162.899994  164.619995  164.619995
#
#      Volume  previous_closing_price
# 0  14345400                     NaN
# 1  11770700              162.289993
# 2  15607800              162.559998
# 3  15858500              160.039993
# 4  18737100              161.889999

# %%
fb_finance['previous_closing_price'] = fb_finance['previous_closing_price']-fb_finance['Close']
fb_finance.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0  2/19/2019  160.500000  164.149994  160.330002  162.289993  162.289993
# 1  2/20/2019  162.250000  163.720001  161.250000  162.559998  162.559998
# 2  2/21/2019  161.929993  162.240005  159.589996  160.039993  160.039993
# 3  2/22/2019  160.580002  162.410004  160.309998  161.889999  161.889999
# 4  2/25/2019  163.070007  166.070007  162.899994  164.619995  164.619995
#
#      Volume  previous_closing_price
# 0  14345400                     NaN
# 1  11770700               -0.270005
# 2  15607800                2.520005
# 3  15858500               -1.850006
# 4  18737100               -2.729996

# %%
fb_finance['weekly returns'] = (fb_finance['Close']-fb_finance['Close'].shift(7))/fb_finance['Close']*100
fb_finance
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0   2/19/2019  160.500000  164.149994  160.330002  162.289993  162.289993
# 1   2/20/2019  162.250000  163.720001  161.250000  162.559998  162.559998
# 2   2/21/2019  161.929993  162.240005  159.589996  160.039993  160.039993
# 3   2/22/2019  160.580002  162.410004  160.309998  161.889999  161.889999
# 4   2/25/2019  163.070007  166.070007  162.899994  164.619995  164.619995
# 5   2/26/2019  164.339996  166.240005  163.800003  164.130005  164.130005
# 6   2/27/2019  162.899994  163.929993  160.410004  162.809998  162.809998
# 7   2/28/2019  162.369995  163.500000  160.860001  161.449997  161.449997
# 8    3/1/2019  162.600006  163.130005  161.690002  162.279999  162.279999
# 9    3/4/2019  163.899994  167.500000  163.830002  167.369995  167.369995
# 10   3/5/2019  167.369995  171.880005  166.550003  171.259995  171.259995
# 11   3/6/2019  172.899994  173.570007  171.270004  172.509995  172.509995
# 12   3/7/2019  171.500000  171.740005  167.610001  169.130005  169.130005
# 13   3/8/2019  166.199997  169.619995  165.970001  169.600006  169.600006
# 14  3/11/2019  171.600006  174.300003  171.580002  172.070007  172.070007
# 15  3/12/2019  172.089996  173.800003  171.220001  171.919998  171.919998
# 16  3/13/2019  172.320007  174.029999  172.119995  173.369995  173.369995
# 17  3/14/2019  169.759995  171.149994  168.160004  170.169998  170.169998
# 18  3/15/2019  167.160004  167.580002  162.509995  165.979996  165.979996
# 19  3/18/2019  163.570007  163.899994  159.279999  160.470001  160.470001
# 20  3/19/2019  161.479996  163.820007  160.820007  161.570007  161.570007
# 21  3/20/2019  161.500000  166.119995  161.240005  165.440002  165.440002
# 22  3/21/2019  164.889999  166.389999  163.750000  166.080002  166.080002
# 23  3/22/2019  165.649994  167.419998  164.089996  164.339996  164.339996
#
#       Volume  previous_closing_price  weekly returns
# 0   14345400                     NaN             NaN
# 1   11770700               -0.270005             NaN
# 2   15607800                2.520005             NaN
# 3   15858500               -1.850006             NaN
# 4   18737100               -2.729996             NaN
# 5   13784100                0.489990             NaN
# 6   12697500                1.320007             NaN
# 7   11114200                1.360001       -0.520282
# 8   11097800               -0.830002       -0.172541
# 9   18894700               -5.089996        4.379520
# 10  28187900               -3.890000        5.471211
# 11  21531700               -1.250000        4.573648
# 12  18306500                3.379990        2.956306
# 13  13184800               -0.470001        4.003542
# 14  18884000               -2.470001        6.171912
# 15  12155300                0.150009        5.607259
# 16  11973300               -1.449997        3.460806
# 17  18037400                3.199997       -0.640534
# 18  37135400                4.190002       -3.934208
# 19  37524200                5.509995       -5.396650
# 20  25611500               -1.100006       -4.969981
# 21  20211500               -3.869995       -4.007498
# 22  16223000               -0.640000       -3.516375
# 23  16389200                1.740006       -5.494706

# %%
#write to csv
fb_finance.to_csv('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/FB.csv')

# %%
#write to csv columns
fb_finance.to_csv('C:/Users/LocalAdmin/Documents/Python/Untitled Folder/FB.csv', columns=['Volume','weekly returns'])
